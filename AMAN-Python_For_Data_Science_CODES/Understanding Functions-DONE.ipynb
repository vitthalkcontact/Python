# %% [markdown]
# # Functions In Python

# %%
from IPython.display import Image
Image(filename='D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES\\Functions content.png')

# %% [markdown]
# # What is a function?
#
# a function contains a unit of code that is required regularly in the script.
# Programmes write this piece of code inside a function and use that function whereever needed

# %% [markdown]
# # Types of functions:

# %%
from IPython.display import Image
Image(filename='D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES\\typesof.png')

# %%
#Example of system defined fuction
import numpy as np

print(np.mean([3,4,5,10])) #using mean functions
print(np.median([23,34,45]))
# Out:
# 5.5
# 34.0

# %%
#writing a use defined function

#Defining function
def Amanfunction(x):
    return(x+3)

# %%
#Calling/using above function
Amanfunction(12)
Amanfunction(121)
# Out:
# 124

# %%
Amanfunction(120)
# Out:
# 123

# %%
def divide(x,y=5):
    return(x/y)

# %%
divide(15,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-40-9b22e098de81> in <module>
# ----> 1 divide(15,0)
#
# <ipython-input-38-cb9c1da93eb7> in divide(x, y)
#       1 def divide(x,y=5):
# ----> 2     return(x/y)
#
# ZeroDivisionError: division by zero

# %%
#understanding arguments of function

# %%
#understanding Function definition and function call
