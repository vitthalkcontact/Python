# %%
from IPython.display import Image
Image(filename='D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES\\loop.png')

# %%
#A conditional satement is used to run a piece of code after checking a condition
a = 12
b = 12
if b == a:
  print("a is equal to b ")
else:
  print("a is not equal to b")
# Out:
# a is equal to b

# %% [markdown]
# # A loop is
# a sequence of instructions that is
# continually repeated until a certain condition is reached

# %%
from IPython.display import Image
Image(filename='D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES\\looptypes.png')

# %%
#While loops in python
i = 1 #initiliza a variable i with 1

#Running a while loop
while i < 10:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
i = 1
while i < 6:
    print(i)
    if(i==3):
        break
    i+=1
# Out:
# 1
# 2
# 3

# %%
#For loops in python
color = ["Red", "Green", "Blue"]
for x in color:
    print(len(x))
# Out:
# 3
# 5
# 4

# %%
for i range(2, 6)
# Out:
# range(2, 6)

# %%
#Alternate way of writing for loop
for x in range(2, 6):
    print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
#A simple use case of loop

student_marks = [23,32,26,14] #marks obtained by students by class out of 20

percentage_marks = [] #creating an empty list

for i in student_marks:
    percentage_marks.append((i/80)*100)
    
percentage_marks
# Out:
# [28.749999999999996, 40.0, 32.5, 17.5]

# %%
#viewing percentage marks
percentage_marks
# Out:
# [28.749999999999996, 40.0, 32.5, 17.5]

# %%
import sys
print(sys.version)
# Out:
# 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]
