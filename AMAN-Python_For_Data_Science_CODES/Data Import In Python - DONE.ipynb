# %% [markdown]
# # How to import data in python|python data science tutorial(2019)

# %% [markdown]
# # Its All about Data in Data Science

# %%
from IPython.display import Image
Image(filename='D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES\\DataLoc.png')

# %% [markdown]
# # Fetching Data from local files

# %%
#Checking current working directory
import os
os.getcwd()
# Out:
# 'D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES'

# %%
#Set working directory
import os
os.chdir("D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES")

# %%
#Checking current working directory
import os
os.getcwd()
# Out:
# 'D:\\01_DATA_SCIENCE_FINAL\\D-00000-PYTHON\\AMAN-Python_For_Data_Science_CODES'

# %%
#Importing pandas package
import pandas as pd

#Reading the csv file -  fething data
Mydata = pd.read_csv("myfile.csv")

# %%
#View the data
Mydata.head(10)
# Out:
#    industry                                            level  line_code  \
# 0         0                                            total          0
# 1         1                                            total          0
# 2         2                                            total          0
# 3         3                                            total          0
# 4         4                   Agriculture forestry & fishing          1
# 5         5                                      Agriculture          2
# 6         6                               Commercial fishing          2
# 7         7                               Forestry & logging          2
# 8         8  Agriculture forestry & fishing support services          2
# 9         9                                           Mining          1
#
#    value  Unnamed: 4
# 0  D0201       14604
# 1  D0201        3792
# 2  D0201        1071
# 3  D0201         777
# 4  D0201        2268
# 5  D0201        1539
# ...

# %%
#There are other read methods in pd.
pd.read_

# %% [markdown]
# # Fetching Data from Database

# %%
# !pip install MYSQL

# %%
import MySQLdb #Install package - "pip install MySQL"

# %%
#Coonect to database
db = MySQLdb.connect("localhost","root","123456","test" )

# prepare a cursor object using cursor() method
cursor = db.cursor()

# Using SQL query
myquery = "SELECT * from StudentTable"
cursor.execute(myquery)

#fetching results
results = cursor.fetchall()
for row in results:
    stuid = row[0]
    name = row[1]
    # Now print fetched result
    print(stuid, name)
# Out:
# 1 John
# 2 Doe

# %%
'''
create database learn;

use learn;
create table StudentTable
(stuid int,
name varchar(30)
);

insert into StudentTable (stuid, name) values (1, 'John');
insert into StudentTable (stuid, name) values (2, 'Daniel');

select * from StudentTable;
'''
# Out:
# "\ncreate database learn;\n\nuse learn;\ncreate table StudentTable\n(stuid int,\nname varchar(30)\n);\n\ninsert into StudentTable (stuid, name) values (1, 'John');\ninsert into StudentTable (stuid, name) values (2, 'Daniel');\n\nselect * from StudentTable;\n"

# %%
# #Coonect to database
# db = MySQLdb.connect("serverhostid","userid","passwd","schema" )

# # prepare a cursor object using cursor() method
# cursor = db.cursor()

# # Using SQL query
# myquery = "select * from StudentTable"
# cursor.execute(myquery)

# #fetching results
# results = cursor.fetchall()
# for row in results:
#     stuid = row[0]
#     name = row[1]
#     # Now print fetched result
#     print(stuid, name)

# %% [markdown]
# # Fetching Data from Web - Web scrapping

# %%
#loading required packaes
import requests 

#URL variable declaration
URL = "https://en.wikipedia.org/wiki/Machine_learning"

#Getting the data from web
r = requests.get(URL) 

# print(r)

# print(r.text)

#printing Data
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Machine learning - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"897f78d9-2eab-45ad-90b8-11207fb683bf","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Machine_learning","wgTitle":"Machine learning","wgCurRevisionId":983031929,"wgRevisionId":983031929,"wgArticleId":233488,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: uses authors parameter","Articles with short description","Articles with long short description","Short description is different from Wikidat
# ...
