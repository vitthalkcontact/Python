# %%
'is there "any" offers'
# Out:
# 'is there "any" offers'

# %% [markdown]
# ````
# hi
# where is
# quote
# ```

# %% [markdown]
# ```
# hi
# where is
# quote
# ```

# %% [markdown]
# # Concatination

# %%
a="Hello"
b=" tango"
a+b
# Out:
# 'Hello tango'

# %% [markdown]
# ###### repetation

# %%
a="Hello"
a*10
# print(a*10)
# Out:
# 'HelloHelloHelloHelloHelloHelloHelloHelloHelloHello'

# %%
print("#" * 50)
print("scott   " * 10)
print("#" * 50)
print("brian " * 5)
print("#" * 50)
# Out:
# ##################################################
# scott   scott   scott   scott   scott   scott   scott   scott   scott   scott
# ##################################################
# brian brian brian brian brian
# ##################################################

# %% [markdown]
# ###### indexing

# %%
w = "hi where are you"
print(w[-90])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-a8606067eade> in <module>
#       1 w = "hi where are you"
# ----> 2 print(w[-90])
#
# IndexError: string index out of range

# %%
a="0123456789"
print(a[-2:2:-1])
# Out:
# 876543

# %%
a="0123456789"
print(a[-2::])
# Out:
# 89

# %%
a="0123456789"
print(a[-2:2:])

# %% [markdown]
# # slicing

# %% [markdown]
# ![image.png](attachment:image.png)
